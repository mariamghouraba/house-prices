# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### About the data:
#
# The real estate markets, like those in Sydney and Melbourne, present an interesting opportunity for data analysts to analyze and predict where property prices are moving towards. Prediction of property prices is becoming increasingly important and beneficial. Property prices are a good indicator of both the overall market condition and the economic health of a country.
#
# #### Columns:
#
# - Date: Date when the house is ready for sale.
# - Price: Price of the house to be sold.
# - Bedrooms: No. of bedrooms in the house.
# - Bathrooms: No. of bathrooms in the house.
# - Sqft_living: Squarefoot of Living in the house.
# - Sqft_lot: Squarefoot of Floor in the house.
# - Floors: Floors on which living area located.
# - Waterfront: If waterfront available in front of house.
# - View: Vie from the house.
# - Condition: Condition of the house.
# - Sqft_above: Squarefoot above is the space available at roof.
# - Sqft_basement: Squarefoot basement is the space available at the basement.
# - Yr_built: In which year the house is built.
# - Yr_renovated: Year of renovation.
# - Street: On which street house is located.
# - City: City in which the country is located.
# - Statezip: Zip code of the area in which house is located.
# - Country: Country is US.

# %%
data=pd.read_csv("/content/sample_data/data.csv")

# %%
df=data.copy()

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
x=df.drop(['date','street','city','country','statezip','price'],axis=1)
y=df['price']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# start with a model to know if it okey to make data better or not ..baised model

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# score is the accuracy 
# compare bet prediction price and other features

print(model.score(X_train, y_train)*100) #high bais and high variance .... diff bet test , train is high so it wrong model
print(model.score(X_test, y_test)*100)
# Out:
# 39.11839148648858
# 9.612104439332459

# %%
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 4452       3.0       1.00         1040      6860     2.0           0     0
# 2457       5.0       2.75         3320     23760     2.0           0     0
# 1390       3.0       2.25         2370    217800     2.0           0     0
# 3402       4.0       1.75         2085    174240     1.0           0     0
# 3197       4.0       2.50         2450     55387     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 1033       3.0       1.50         1270      1443     3.0           0     0
# 3264       2.0       1.00          970      5500     1.0           0     0
# 1653       5.0       2.75         2080     13189     2.0           0     0
# 2607       4.0       2.50         3070     34412     1.0           0     3
# 2732       3.0       1.75         1700      8432     1.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
y_test
# Out:
# 991     2.890000e+05
# 2824    4.299000e+05
# 1906    1.290000e+05
# 1471    6.000000e+05
# 1813    1.298000e+06
#             ...
# 1523    3.250000e+05
# 144     3.667500e+05
# 388     9.850000e+05
# 4395    1.353333e+05
# 1669    3.800000e+05
# Name: price, Length: 1380, dtype: float64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(np.abs(df.corr()),annot=True)
# Out:
# <AxesSubplot:>

# %%
# corr bet two features must not high

# %%
df[df==0].count()
# Out:
# date                0
# price              49
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4567
# view             4140
# condition           0
# sqft_above          0
# sqft_basement    2745
# yr_built            0
# yr_renovated     2735
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
df=df[df['price'] !=0]

# %%
df[df==0].count()
# Out:
# date                0
# price               0
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4521
# view             4103
# condition           0
# sqft_above          0
# sqft_basement    2718
# yr_built            0
# yr_renovated     2706
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
df=df[df['bedrooms'] !=0]

# %%
df=df[df['bathrooms'] !=0]

# %%
df[df==0].count()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4519
# view             4102
# condition           0
# sqft_above          0
# sqft_basement    2716
# yr_built            0
# yr_renovated     2706
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
df['view'].unique()
# Out:
# array([0, 4, 1, 2, 3])

# %%
plt.hist(df['price']);

# %%
plt.figure(figsize=(20,20))
sns.histplot(data=df,x='price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
# there is outliers so we will remove it 
# اجيب ال مين واشوف الحاجات االلي علي بعد sd معين واشيلها 
# z score, boxplot

# %%
from scipy import stats
#df[np.abs(stats.zscore(df['price']))< 3]

df=df[(stats.zscore(df['price'])> -3) & (stats.zscore(df['price'])< 3) ]

# %%
plt.figure(figsize=(15,15))
sns.histplot(data=df,x='price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))

sns.scatterplot(data=df,x='sqft_living',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df['sqft_living']= np.where(df['sqft_living']>6000,6000,df['sqft_living'])

# %%
sns.scatterplot(data=df,x='sqft_living',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(data=df,x='sqft_above',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
df['sqft_above']= np.where(df['sqft_above']>5000,5000,df['sqft_above'])

# %%
sns.scatterplot(data=df,x='sqft_above',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
sns.scatterplot(data=df,x='sqft_basement',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %%
df['sqft_basement']= np.where(df['sqft_basement']>2250,2250,df['sqft_basement'])

# %%
sns.scatterplot(data=df,x='sqft_basement',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %%
sns.barplot(data=df,x='bedrooms',y='price')
# be linear line
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.groupby('bedrooms').price.agg((len,min,max))
# Out:
#            len       min        max
# bedrooms
# 1.0         37   80000.0   540000.0
# 2.0        561    7800.0  1695000.0
# 3.0       2019   83300.0  2147500.0
# 4.0       1499   84350.0  2199900.0
# 5.0        327  185000.0  2238888.0
# 6.0         57  175000.0  2180000.0
# 7.0         12  280000.0  1950000.0
# 8.0          2  340000.0  1970000.0
# 9.0          1  599999.0   599999.0

# %%
df['bedrooms']= np.where(df['bedrooms']>6,6,df['bedrooms'])

# %%
sns.barplot(data=df,x='bedrooms',y='price')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.barplot(data=df,x='bathrooms',y='price')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
df.groupby('bathrooms').price.agg((len,min,max))
# Out:
#             len        min        max
# bathrooms
# 0.75         17    80000.0   562100.0
# 1.00        736     7800.0  2110000.0
# 1.25          3   321950.0   545000.0
# 1.50        287   107500.0  2199900.0
# 1.75        628   120750.0  2100000.0
# 2.00        424    83300.0  1755000.0
# 2.25        411   132250.0  2110000.0
# 2.50       1180   168000.0  1920000.0
# 2.75        270   188000.0  2180000.0
# 3.00        162   235000.0  1990000.0
# 3.25        128   300000.0  1900000.0
# 3.50        157   248000.0  2147500.0
# 3.75         34   195000.0  2065000.0
# 4.00         21   315000.0  2000000.0
# 4.25         18   540000.0  2000000.0
# 4.50         23   565000.0  2005000.0
# 4.75          3   480000.0  2200000.0
# 5.00          5   495000.0  1800000.0
# 5.25          3   300000.0  1681000.0
# 5.50          3   925000.0  2150000.0
# 5.75          1   540000.0   540000.0
# 6.50          1  2238888.0  2238888.0

# %%
df['bathrooms']= np.where(df['bathrooms']<1,1,df['bathrooms'])

# %%
df['bathrooms']= np.where(df['bathrooms']==1.25,1,df['bathrooms'])

# %%
df['bathrooms']= np.where(df['bathrooms']>4.5,4.5,df['bathrooms'])

# %%
sns.barplot(data=df,x='bathrooms',y='price')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
sns.barplot(data=df,x='floors',y='price')
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
df.groupby('floors').price.agg((len,min,max))
# Out:
#          len       min        max
# floors
# 1.0     2144    7800.0  2199900.0
# 1.5      436  132500.0  2027000.0
# 2.0     1769   84350.0  2238888.0
# 2.5       40  195000.0  1990000.0
# 3.0      125  288790.0  2000000.0
# 3.5        1  563500.0   563500.0

# %%
df['floors']= np.where(df['floors']==3.5,3,df['floors'])

# %%
sns.barplot(data=df,x='floors',y='price')
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
sns.barplot(data=df,x='waterfront',y='price')
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
# anova compare bet categorical and numerical

# %%
df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(np.abs(df.corr()),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(['date','street','city','country','statezip','price','yr_built','yr_renovated','condition','sqft_lot'],axis=1)
y=df['price']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# start with a model to know if it okey to make data better or not ..baised model

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# score is the accuracy 
# compare bet prediction price and other features

print(model.score(X_train, y_train)*100) #high bais and high variance .... diff bet test , train is high so it wrong model
print(model.score(X_test, y_test)*100)
# Out:
# 49.47544825304795
# 49.66592398611379

# %%
# bias is improved variance disappeared

# %%
df.drop(['yr_built','yr_renovated','condition','sqft_lot','sqft_above'],axis=1, inplace=True)

# %%
df
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  313000.000000       3.0       1.50         1340
# 2     2014-05-02 00:00:00  342000.000000       3.0       2.00         1930
# 3     2014-05-02 00:00:00  420000.000000       3.0       2.25         2000
# 4     2014-05-02 00:00:00  550000.000000       4.0       2.50         1940
# 5     2014-05-02 00:00:00  490000.000000       2.0       1.00          880
# ...                   ...            ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
# ...

# %%
df['country'].nunique()
# Out:
# 1

# %%
df['street'].nunique()
# Out:
# 4441

# %%
df['street'].value_counts()
# اقصي قيمة متكررة اربع مرات بس ف نشيلها ملهاش لازمة
# Out:
# 2520 Mulberry Walk NE     4
# 2500 Mulberry Walk NE     3
# 1018 NE 96th St           2
# 2300 14th Ave S           2
# 23620 SE 243rd Pl         2
#                          ..
# 33415 41st Ave SW         1
# 4801-4999 229th Ave SE    1
# 1505 S Plum St            1
# 1215 N 50th St            1
# 18717 SE 258th St         1
# Name: street, Length: 4441, dtype: int64

# %%
df['city'].nunique()
# Out:
# 44

# %%
df['statezip'].nunique()
# Out:
# 77

# %%
plt.figure(figsize=(15,15))
sns.barplot(data=df,x='city',y='price');
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,15))
sns.barplot(data=df,x='statezip',y='price');
plt.xticks(rotation=90);

# %%
# chosse that get high variance bet zip and city .... best zip

# %%
df.groupby('city').price.agg('mean').std()
# Out:
# 272359.36431756953

# %%
df.groupby('statezip').price.agg('mean').std()
# Out:
# 234396.8336131362

# %%
# above if i can not find variance by my eyes

# %%
df.drop(['date','street','country','city'],axis=1, inplace=True)

# %%
df
# Out:
#               price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0     313000.000000       3.0       1.50         1340     1.5           0
# 2     342000.000000       3.0       2.00         1930     1.0           0
# 3     420000.000000       3.0       2.25         2000     1.0           0
# 4     550000.000000       4.0       2.50         1940     1.0           0
# 5     490000.000000       2.0       1.00          880     1.0           0
# ...             ...       ...        ...          ...     ...         ...
# 4595  308166.666667       3.0       1.75         1510     1.0           0
# 4596  534333.333333       3.0       2.50         1460     2.0           0
# 4597  416904.166667       3.0       2.50         3010     2.0           0
# 4598  203400.000000       4.0       2.00         2090     1.0           0
# 4599  220600.000000       3.0       2.50         1490     2.0           0
#
#       view  sqft_basement  statezip
# 0        0              0  WA 98133
# ...

# %%
# hot encoding using with categorical data to be used in model 
# categorical converted into 0,1 or removed if it not needed like city
df=pd.get_dummies(df,columns=['statezip'],prefix='state_zip')

# %%
df
# Out:
#               price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0     313000.000000       3.0       1.50         1340     1.5           0
# 2     342000.000000       3.0       2.00         1930     1.0           0
# 3     420000.000000       3.0       2.25         2000     1.0           0
# 4     550000.000000       4.0       2.50         1940     1.0           0
# 5     490000.000000       2.0       1.00          880     1.0           0
# ...             ...       ...        ...          ...     ...         ...
# 4595  308166.666667       3.0       1.75         1510     1.0           0
# 4596  534333.333333       3.0       2.50         1460     2.0           0
# 4597  416904.166667       3.0       2.50         3010     2.0           0
# 4598  203400.000000       4.0       2.00         2090     1.0           0
# 4599  220600.000000       3.0       2.50         1490     2.0           0
#
#       view  sqft_basement  state_zip_WA 98001  state_zip_WA 98002  ...  \
# ...

# %%
x=df.drop(['price'],axis=1)
y=df['price']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# start with a model to know if it okey to make data better or not ..baised model

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# score is the accuracy 
# compare bet prediction price and other features

print(model.score(X_train, y_train)*100) #high bais and high variance .... diff bet test , train is high so it wrong model
print(model.score(X_test, y_test)*100)
# Out:
# 77.8036160002916
# 76.13384820066707

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
model.coef_
# Out:
# array([-1.49669554e+04,  1.82064212e+04,  2.23723913e+02, -4.14911399e+04,
#         3.07141849e+05,  5.59543280e+04, -1.03042612e+02, -4.41973784e+13,
#        -4.41973784e+13, -4.41973785e+13, -4.41973777e+13, -4.41973781e+13,
#        -4.41973781e+13, -4.41973781e+13, -4.41973782e+13, -4.41973784e+13,
#        -4.41973783e+13, -4.41973783e+13, -4.41973784e+13, -4.41973784e+13,
#        -4.41973785e+13, -4.41973782e+13, -4.41973783e+13, -4.41973783e+13,
#        -4.41973782e+13, -4.41973785e+13, -4.41973784e+13, -4.41973785e+13,
#        -4.41973781e+13, -4.41973783e+13, -4.41973784e+13, -4.41973777e+13,
#        -4.41973779e+13, -4.41973784e+13, -4.41973784e+13, -4.41973785e+13,
#        -4.41973783e+13, -4.41973784e+13, -4.41973782e+13, -4.41973782e+13,
#        -4.41973784e+13, -4.41973783e+13, -4.41973784e+13, -4.41973784e+13,
#        -4.41973784e+13, -4.41973784e+13, -4.41973782e+13, -4.41973784e+13,
# ...

# %%
x=df.drop(['price'],axis=1)
y=df['price']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# start with a model to know if it okey to make data better or not ..baised model

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# score is the accuracy 
# compare bet prediction price and other features

print(model.score(X_train, y_train)*100) #high bais and high variance .... diff bet test , train is high so it wrong model
print(model.score(X_test, y_test)*100)
# Out:
# 78.69421642992155
# -3134500719590429.5

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([511221.1875  , 764688.      , 497248.265625, ..., 226183.34375 ,
#        541170.984375, 499708.015625])

# %%
# distibutionn
